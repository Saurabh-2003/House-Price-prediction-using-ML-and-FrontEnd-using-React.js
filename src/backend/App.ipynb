# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Data Exploration

# %%
# Visualize bedroomwise
sns.countplot(x = df['bedrooms'])
#we can see most common house have 3 bedrooms
# Out:
# <AxesSubplot: xlabel='bedrooms', ylabel='count'>

# %%
#visualize using latitude and longitude features
sns.jointplot(x =df['lat'], y=df['long'])
# We can see more house are around longitude -122.2 to -122.4
# and latitude around 47.7 to 47.8

# %% [markdown]
# ## We saw the common locations and now we’re going to see few common factors affecting the prices of the house

# %%
# We can see increasing size of living room also increases the price
sns.scatterplot(x=df['price'],y=df['sqft_living'])
plt.plot([df['price'].min(), df['price'].max()], [df['sqft_living'].min(), df['sqft_living'].max()], 'k--', lw=4)

# %%
# relationship between price and longitude
sns.scatterplot(x= df['price'], y= df['long'])
# Out:
# <AxesSubplot: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x = df['bedrooms'], y = df['price'])
#From here we can assume that house having 3-6 bedrooms have highest prices
# Out:
# <AxesSubplot: xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(x =df['sqft_living'], y = df['sqft_basement'])
# We can see with increasing size of living room , basement size also increases
# Out:
# <AxesSubplot: xlabel='sqft_living', ylabel='sqft_basement'>

# %%
sns.scatterplot(x=df['floors'],y=df['price'])
# Out:
# <AxesSubplot: xlabel='floors', ylabel='price'>

# %%
sns.scatterplot(x=df['condition'], y = df['price'])
# Out:
# <AxesSubplot: xlabel='condition', ylabel='price'>

# %% [markdown]
# ## Now we reduce some features from dataset to reduce complexity of the dataset and only retain those we find useful

# %%
X = df.drop(['date', 'id', 'price', 'waterfront', 'view', 'grade', 'sqft_above', 'zipcode', 'sqft_living15', 'sqft_lot15'], axis = 1)
y = df['price']

# %%
X.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21613.000000  21613.000000  21613.000000  2.161300e+04  21613.000000
# mean       3.370842      2.114757   2079.899736  1.510697e+04      1.494309
# std        0.930062      0.770163    918.440897  4.142051e+04      0.539989
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1427.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.618000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.068800e+04      2.000000
# max       33.000000      8.000000  13540.000000  1.651359e+06      3.500000
#
#           condition  sqft_basement      yr_built  yr_renovated           lat  \
# count  21613.000000   21613.000000  21613.000000  21613.000000  21613.000000
# mean       3.409430     291.509045   1971.005136     84.402258     47.560053
# ...

# %% [markdown]
# ## Using linear Regression on the dataset

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
# Splitting the dataset into training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=2)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Calculating the r-score
lr.score(X_test, y_test)
# Out:
# 0.6153206218985313

# %%
# Calculating the Mean_Squared_Error
from sklearn.metrics import mean_squared_error
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 52945887137.01731

# %%
y_actual = pd.DataFrame(y_test).to_numpy().ravel()
df = pd.DataFrame({'Actual': y_actual, 'Predicted': y_pred})

# Plot the predicted vs actual values using Seaborn's scatterplot
sns.scatterplot(x='Actual', y='Predicted', data=df)

# Add a diagonal line for reference
plt.plot([df['Actual'].min(), df['Actual'].max()], [df['Actual'].min(), df['Actual'].max()], 'k--', lw=4)

# Set the title and axis labels
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')

# Show the plot
plt.show()

# %% [markdown]
# ### we can see from above that the r2 score is low and mse score is very large that means our linear regression model is not performing well

# %% [markdown]
# ## Using Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(n_estimators = 100, learning_rate = 0.22, min_samples_split=2, max_depth=5, loss = 'squared_error')

# %%
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.22, max_depth=5)

# %%
gbr.score(X_test, y_test)
# Out:
# 0.8286610269883516

# %%
# Calculating the Mean_Squared_Error
from sklearn.metrics import mean_squared_error
y_pred = gbr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 23582480485.48707

# %%
y_actual = pd.DataFrame(y_test).to_numpy().ravel()
df = pd.DataFrame({'Actual': y_actual, 'Predicted': y_pred})

# Plot the predicted vs actual values using Seaborn's scatterplot
sns.scatterplot(x='Actual', y='Predicted', data=df)

# Add a diagonal line for reference
plt.plot([df['Actual'].min(), df['Actual'].max()], [df['Actual'].min(), df['Actual'].max()], 'k--', lw=4)

# Set the title and axis labels
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')

# Show the plot
plt.show()

# %% [markdown]
# ### We can see from above that the r2 score is .8265.... which is significantly better than the linear regression and MSE is also more than half of it that is mean our Gradient Boosting Regressor is performing good on the Model. Now, we will explore some more model and will chose the best one out of it

# %% [markdown]
# # using Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators = 100, random_state = 2 )

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=2)

# %%
# Calculating R2 score
rfr.score(X_test, y_test)
# Out:
# 0.8276436757755811

# %%
# Calculating the Mean_Squared_Error
from sklearn.metrics import mean_squared_error
y_pred = rfr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 23722505050.245136

# %%
# Visualization of Accuracy
y_actual = pd.DataFrame(y_test).to_numpy().ravel()
df = pd.DataFrame({'Actual': y_actual, 'Predicted': y_pred})

# Plot the predicted vs actual values using Seaborn's scatterplot
sns.scatterplot(x='Actual', y='Predicted', data=df)

# Add a diagonal line for reference
plt.plot([df['Actual'].min(), df['Actual'].max()], [df['Actual'].min(), df['Actual'].max()], 'k--', lw=4)

# Set the title and axis labels
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')

# Show the plot
plt.show()

# %% [markdown]
# ### from above scores we can see that both the random forest regressor and Gradient Boosting regressor are performing the same

# %% [markdown]
# ## Using XGBoost Regressor

# %%
import xgboost as xgb
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=0.3, learning_rate=0.22,max_depth=5, alpha=10, n_estimators=100)

# %%
xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.22, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %%
#r2 Score of the Model
xg_reg.score(X_test, y_test)
# Out:
# 0.8134131834589455

# %%
# Calculating the Mean_Squared_Error
from sklearn.metrics import mean_squared_error
y_pred = xg_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 25681138871.011154

# %% [markdown]
# ### After Playing around with the learning rate of the xgboost we made its score better but it still doesn't perform better than the RandomForest and GradientBoostRegressor

# %% [markdown]
# ## So at last, we determine the best model among all is the Gradient Boosting Regression with the highest R2 Score and Lowest MSE. So we will save our model as pickle file and use it in our backend for the project

# %%
import pickle
pickle.dump(gbr, open('gbr.pkl', 'wb'))
